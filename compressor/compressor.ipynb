# %% [markdown]
# # 概要
# Google Drive上の音声ファイルを圧縮して容量を削減する。
#
# ---
# # 使用方法
#
# # 1. 設定
# スクリプト先頭の３つの項目: FILE_PATH, BITRATE, KEEP_ORIGINAL を設定する。
#
# ### 1.1. FILE_PATH
# この項目では、圧縮したい音声ファイルの場所を指定する。例えば以下。
# ```python
# FILE_PATH = '共有/共有音源/A音源/A001-050/00-A001 01 ゆれる秋.mp3'
# ```
#
# また、音声ファイルではなくフォルダを指定した場合は、そのフォルダに含まれる
# 全てのファイルを圧縮する。例えば以下はA音源を全て圧縮する。
# ```python
# FILE_PATH = '共有/共有音源/A音源'
# ```
#
# ### 1.2. BITRATE
# 圧縮後の音声ファイルのビットレート（音質）を指定する。
# 値が大きいほど音質がよい。通常、 192 [kbps] または 128 [kbps] を選択する。
#
# 192 [kbps] は、室内録音においては事実上の音質の限界であり、これより大きい値を指定する意味はない。叡風会のレコーダーで録音するとこのビットレートになる。
#
# 128 [kbps] は、多くの人にとって 192 [kbps] と遜色ない音質でありながら容量もそこそこ小さくバランスが良い。
#
# 尚、圧縮前の音声ファイルのビットレートが指定する `BITRATE` の値より既に小さかった場合、そのファイルはPASSされ、そのファイルに変更は加えられない。
#
# ### 1.3. KEEP_ORIGINAL
# 圧縮前のファイルを残すか/残さないか(True/False)を指定する。
#
# True の場合、圧縮前のファイルは"orig.[元ファイルの名前].mp3"という名前に変更され、もとのディレクトリに残される。
#
# False の場合、圧縮前のファイルはゴミ箱を含む全てのファイルシステムから完全に失われ、復元することはできない。
#
# # 2. 実行
# スクリプト左上の実行ボタンをクリックして実行する。
# 進捗状況は、スクリプトの下に表示される。

# %%
# スクリプト

# User Settings
FILE_PATH = 'tunes'
BITRATE = 128
KEEP_ORIGINAL = True

# env
MOUNT_POINT = '.' # is always '/content/drive' in Google Drive
BASE_PATH = f'{MOUNT_POINT}/{FILE_PATH}' # absolute path

# conf
CODEC = 'mp3' # codec [mp3, wav, aac, flac]
(IGNORE, PASS, COMPRESS) = ('IGNORE', 'PASS', 'COMPRESS') # select-case literal

"""
# install ffmpeg 
# !pip ffmpeg

# mount Google Drive on colab
from google.colab import drive
drive.mount(MOUNT_POINT)
"""

# import libraries
import ffmpeg
import shutil
from os import path, remove, listdir as ls
import re


# Search the given directory recursively and apply
# the cbf (callback-function) to all files
def tree(directory, callback): # pure
    for file in ls(directory):
        if path.isdir(f'{directory}/{file}'):
            tree(f'{directory}/{file}', callback)
        else:
            callback(f'{directory}/{file}')


# Select operations by file attributes.
def select_case(file_path):
    if re.match(r'.*\.mp3', file_path) is None:
        return IGNORE # file is not a mp3
    bps = int(ffmpeg.probe(file_path)['streams'][0]['bit_rate'])
    kbps = int(bps*1e-3)
    if (kbps <= BITRATE):
        print(f'{file_path}, {PASS}, {kbps}kbps')
        return PASS # original file size is small enough 
    else:
        print(f'{file_path}, {COMPRESS}, {kbps}kbps -> {BITRATE}kbps')
        return COMPRESS


# Wrap ffmpeg
def compress(file_path):
    orig = f'{path.dirname(file_path)}/orig.{path.basename(file_path)}'
    shutil.copyfile(file_path, orig)
    (ffmpeg.input(orig)
        .output(file_path, format=CODEC, audio_bitrate=f'{BITRATE}k')
        .run(overwrite_output=True, quiet=True))
    if not KEEP_ORIGINAL:
        remove(orig)


def execute(file_path):
    case = select_case(file_path)
    (case == IGNORE) and None
    (case == PASS) and None
    (case == COMPRESS) and compress(file_path)


### executable section
print('file name, action, bitrate')
if path.isdir(BASE_PATH):
    tree(directory=BASE_PATH, callback=execute)
else:
    execute(BASE_PATH)
# Out:
# file name, action, bitrate
# ./tunes/00-A022 03 秋の色種.mp3, PASS, 128kbps
# ./tunes/orig.orig.00-A022 07 鹿の遠音.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/orig.00-A022 07 鹿の遠音.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 01 二つの田園詩.mp3, PASS, 128kbps
# ./tunes/00-A022 08 五段砧.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 06 五木の子守歌.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/orig.00-A022 04 刈干切唄.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/00-A022 06 五木の子守歌.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 02 秋、そして.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/00-A022 05 残月.mp3, PASS, 128kbps
# ./tunes/00-A022 02 秋、そして.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 05 残月.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/00-A022 07 鹿の遠音.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 08 五段砧.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/orig.orig.00-A022 01 二つの田園詩.mp3, COMPRESS, 192kbps -> 128kbps
# ./tunes/00-A022 04 刈干切唄.mp3, PASS, 128kbps
# ./tunes/00-A022 01 二つの田園詩.mp3, PASS, 128kbps
# ./tunes/orig.00-A022 03 秋の色種.mp3, COMPRESS, 192kbps -> 128kbps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/t98/Work/af-desc/compressor/compressor.ipynb Cell 3 in <cell line: 66>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a> print('file name, action, bitrate')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> if path.isdir(BASE_PATH):
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a>     tree(directory=BASE_PATH, callback=execute)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a> else:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=68'>69</a>     execute(BASE_PATH)
#
# /home/t98/Work/af-desc/compressor/compressor.ipynb Cell 3 in tree(directory, callback)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     tree(f'{directory}/{file}', callback)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> else:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     callback(f'{directory}/{file}')
#
# /home/t98/Work/af-desc/compressor/compressor.ipynb Cell 3 in execute(file_path)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=58'>59</a> (case == IGNORE) and None
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a> (case == PASS) and None
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=60'>61</a> (case == COMPRESS) and compress(file_path)
#
# /home/t98/Work/af-desc/compressor/compressor.ipynb Cell 3 in compress(file_path)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> orig = f'{path.dirname(file_path)}/orig.{path.basename(file_path)}'
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> shutil.copyfile(file_path, orig)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> (ffmpeg.input(orig)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a>     .output(file_path, format=CODEC, audio_bitrate=f'{BITRATE}k')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a>     .run(overwrite_output=True, quiet=True))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a> if not KEEP_ORIGINAL:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/t98/Work/af-desc/compressor/compressor.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a>     remove(orig)
#
# File ~/Work/af-desc/venv/lib/python3.10/site-packages/ffmpeg/_run.py:322, in run(stream_spec, cmd, capture_stdout, capture_stderr, input, quiet, overwrite_output)
#     299 """Invoke ffmpeg for the supplied node graph.
#     300
#     301 Args:
#    (...)
#     311 Returns: (out, err) tuple containing captured stdout and stderr data.
#     312 """
#     313 process = run_async(
#     314     stream_spec,
#     315     cmd,
#    (...)
#     320     overwrite_output=overwrite_output,
#     321 )
# --> 322 out, err = process.communicate(input)
#     323 retcode = process.poll()
#     324 if retcode:
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/subprocess.py:1149, in Popen.communicate(self, input, timeout)
#    1146     endtime = None
#    1148 try:
# -> 1149     stdout, stderr = self._communicate(input, endtime, timeout)
#    1150 except KeyboardInterrupt:
#    1151     # https://bugs.python.org/issue25942
#    1152     # See the detailed comment in .wait().
#    1153     if timeout is not None:
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/subprocess.py:2000, in Popen._communicate(self, input, endtime, orig_timeout)
#    1993     self._check_timeout(endtime, orig_timeout,
#    1994                         stdout, stderr,
#    1995                         skip_check_and_raise=True)
#    1996     raise RuntimeError(  # Impossible :)
#    1997         '_check_timeout(..., skip_check_and_raise=True) '
#    1998         'failed to raise TimeoutExpired.')
# -> 2000 ready = selector.select(timeout)
#    2001 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2003 # XXX Rewrite these to use non-blocking I/O on the file
#    2004 # objects; they are no longer using C stdio!
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
