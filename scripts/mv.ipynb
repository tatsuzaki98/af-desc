# %%
import shutil

# %%
[
    ["2002年\(B18~26\)",        "B_2002年_018-026"],
    ["2003年\(B30~38 B48~50\)", "B_2003年_030-038 B48~50"],
    ["2004年\(B39~44 B52~54\)", "B_2004年_039-044 B52~54"],
    ["2005年\(B55~59\)",        "B_2005年_055-059"],
    ["2006年\(B60~73\)",        "B_2006年_060-073"],
    ["2007年\(B70~77\)",        "B_2007年_070-077"],
    ["2008年\(B81\)",           "B_2008年_081-081"],
    ["2009年\(B85~87\)",        "B_2009年_085-087"],
    ["2010年\(B85~88\)",        "B_2010年_085-088"],
    ["2011年\(B89~93\)",        "B_2011年_089-093"],
    ["2012年\(B96~100\)",       "B_2012年_096-100"],
    ["2013年\(B101~104\)",      "B_2013年_101-104"],
    ["2014年\(B105~109\)",      "B_2014年_105-109"],
    ["2015年\(B110~118\)",      "B_2015年_110-118"],
    ["2016年\(B119~127\)",      "B_2016年_119-127"],
    ["2017年\(B131~134\)",      "B_2017年_131-134"],
    ["2018年\(B135~145\)",      "B_2018年_135-145"],
    ["2019年\(B146~158\)",      "B_2019年_146-158"],
    ["2021年\(B159\)",          "B_2021年_159-159"],
    ["2022年\(B160~\)",         "B_2022年_160-ltn"],
]
